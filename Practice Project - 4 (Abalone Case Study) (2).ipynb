# %%
import pandas as pd

# %%
df=pd.read_csv('abalone.csv')

df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
# looking at the head of the data
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
# describe the data

df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
# information of the data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
# checking if there is any NULL data 

df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
# pairplot

sns.pairplot(df)

# %%
# checking the columns of the data

df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
# heatmap

sns.heatmap(df[[ 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
       'Viscera weight', 'Shell weight', 'Rings']])
# Out:
# <AxesSubplot:>

# %%
# checkig the values of sex

df['Sex'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# plotting a hue plot


plt.figure(figsize=(20,8))
sns.boxplot(df['Rings'], df['Length'], hue = df['Sex'], palette = 'pastel')
plt.title('Rings vs length and sex', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Rings vs length and sex')

# %%
plt.figure(figsize=(20,8))
sns.boxplot(df['Rings'], df['Diameter'], hue = df['Sex'], palette = 'pastel')
plt.title('Rings vs diameter and sex', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Rings vs diameter and sex')

# %%
# ring vs weight

plt.figure(figsize=(20,8))
sns.swarmplot(df['Rings'], df['Whole weight'])
plt.title('Rings vs weight')
# Out:
# Text(0.5, 1.0, 'Rings vs weight')

# %%
# ring vs shucked weight

plt.figure(figsize=(20,8))
sns.swarmplot(df['Rings'], df['Shucked weight'], palette = 'dark')
plt.title('Rings vs shucked weight')
# Out:
# Text(0.5, 1.0, 'Rings vs shucked weight')

# %%
# ring vs viscera weight

plt.figure(figsize=(20,8))
sns.stripplot(df['Rings'], df['Viscera weight'])
plt.title('Rings vs Viscera Weight')
# Out:
# Text(0.5, 1.0, 'Rings vs Viscera Weight')

# %%
# ring vs shell weight

plt.figure(figsize=(20,8))
sns.regplot(df['Rings'], df['Shell weight'])
plt.title('Rings vs Shell weight')
# Out:
# Text(0.5, 1.0, 'Rings vs Shell weight')

# %%
import matplotlib.pyplot as plt


df.corr()['Rings'].sort_values()
# Out:
# Shucked weight    0.420884
# Viscera weight    0.503819
# Whole weight      0.540390
# Length            0.556720
# Height            0.557467
# Diameter          0.574660
# Shell weight      0.627574
# Rings             1.000000
# Name: Rings, dtype: float64

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])

# %%
# splitting the dependent and independent variables

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %%
x=df.iloc[:,:-1]

# %%
x
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# 3             0.1140        0.1550
# 4             0.0395        0.0550
# ...              ...           ...
# 4172          0.2390        0.2490
# 4173          0.2145        0.2605
# 4174          0.2875        0.3080
# 4175          0.2610        0.2960
# 4176          0.3765        0.4950
#
# [4177 rows x 8 columns]

# %%
# getting the shapes
print("Shape of x:", x.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of x: (4177, 8)
# Shape of y: (4177,)

# %%
# train test split

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# getting the shapes
print("Shape of x_train :", x_train.shape)
print("Shape of x_test :", x_test.shape)
print("Shape of y_train :", y_train.shape)
print("Shape of y_test :", y_test.shape)
# Out:
# Shape of x_train : (3341, 8)
# Shape of x_test : (836, 8)
# Shape of y_train : (3341,)
# Shape of y_test : (836,)

# %%
# MODELLING
# RANDOM FOREST REGRESSOR

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
model = RandomForestClassifier()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
print('predict value and actual value',y_pred,y_test)
# Out:
# predict value and actual value [19  9 10  4 11 10  8  8  7 10  7  5  8  7  5  9  9 15 12  7  7  6  9  7
#   9 11  4 12  8 11 11  4 10 11  6  8  8  9  7 10 11 11 13 13  9  9  8 10
#  13  8  9  6  8 13  8  8  5  9  6  6 10  8 10  8  7 11 11 10  8 11  8 14
#  11  8  8  9  9 10 10  8 10  5  6 12 10  8 10 10  4  6  8 10  8  6 15  5
#   9 11 14 11  9 12 10  9  5 11  8  7 10 14  9 12 10  9 14 11  9 13  6  9
#   7 13  6  9 13 10  9 11  7  9  9  8  8 11 11 10  9  8  6 10 14 12  8  8
#  10  8  9  8  8  6  9 11  8  9  9  7 10  7 13  9  8 10  9 10  5 19  6  6
#  11  9  9  4  7 10 11 10  5  8  7 13  8  9  8  8 13 10  9  8  7  9 10  9
#   8 10 10 10  8  8  4 11 12 14 12  9  9 11  5 10  8 13  4 10 10  9 13 10
#   9 10  5 11 11 10  8 10 10 15 10  9 12 10  8  7  6 11  8  9  8  4  8  9
#   8 10 10 11 10 10 10  8  8 12  9  8 12 10 11 17  7 10 11 12 10  8  9  7
#  10  8  8  6  7  6  9  8 10  7  6 11 14  9  9 13  6 11  7  9  9 11  7 10
#   9 13  8  8  5  8  6  8  6  5  9 10  7  8 12  9  7  7 10  8  9  9 10 11
#   7  9 13 12 12  6  9 10 11  9  9 11  9 10  9 10 14 10  8 11  5 10  9 11
#   8  8 11 11  8  8 10 10 10  8  5 12 17  6  5  9 11 11 11  8  9 11  8  9
#   9  8  8  9  9  4  6  8  8  9 10  7  9  8 10 10 10  7 12  4  8  9 10 12
#   5 10 11  8  8  6 16 11 10 10 17  7  9  8 10 12  8  9  7 11  9 11  5 11
#  16 10 12  8 10 10 10 10 13 10 11 11  9  9  9 10  6  8 10  9  9 12  8 11
#   8 14 11  9 10 10  9 11  7  6 12  8  6  6 12  5 10 10  4  6 10  6  5  7
#   9  8 10 14  7 11  9  9  9 11  7 21  9  8  9  9  8 16  8 11  8  7  7  9
#  10 11  9  9 12 10  8  9  8 11  4  9 11 11  9  7  7  5 10 10  8 10  7 12
#  10 10 13 16  7  5 12  9 10 14 10  8  9 10 10  9 10  8 10 10  7 10  8 12
#   8  8  7  6 12 10  5  8 11 10  9 11  7  9  7 12  7 10  8  8  9 10  9 12
#   6 11 11  8 10  8 10  8 10  9  9  9 12  6  8  9  9  7 11  9  8  8  9  7
#  10  9 11  4 14  6  5  7  7  9 18 11  8 10  5  9  9 10 13 11  4  6  6 10
#   8 11 10 12 10 10 10  6  8 10  6 12  9  8 10 11  8  7 11  9 10 11  7  9
#   9 13  8 10  8  9 12  6 10  7  9 10  4 11  9  9 15 11 10 10 11  8  8 10
#  11 13 10  9  9  9  6 10  7  6  9 10 14  8 14 16 18  8  8  7  6 14  9 11
#  15 13  4  7  8  6  8 16 10  8 10 13  9  7 17  9 10 13 10 11 10 10  8  9
#  11 16  8  8  7 10  8 11  8  9  7  8 11 10  6  5  6  9  7  8  9  8  6  7
#  15  4 13  6 17  5  9  8 13 10  9  9 10 11  8 10  9 11  8  5 16  8  7  7
#   9  7 10  9  7  9 10  9 10 11 12 10  8  7  9 13  7  6  8  5  9 10 11  9
#  10  6  6  8 13  9  8  8  7 12  8 10 10 17  7  9  7  9  9  8 11 10  8 11
#  12 10 20  9 10 10  4 13  7  7  8  6  7  8  9 10  7  8  8  8 10 11 11  8
#   9 10 13  8  6  9 11  6  8  9 10  9  6  7  8 10  8  6 19  4] 668     13
# 1580     8
# 3784    11
# 463      5
# 2615    12
#         ..
# 575     11
# 3231    12
# 1084     7
# 290     17
# 2713     4
# Name: Rings, Length: 836, dtype: int64

# %%
import numpy as np

# evaluation
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE :", rmse)
# Out:
# RMSE : 2.533035322016598

# %%
# r2 score
r2 = r2_score(y_test, y_pred)
print("R2 Score :", r2)
# Out:
# R2 Score : 0.40920035603673577
